# %%
import numpy as np
import pandas as pd

# %%
dat = pd.read_csv('Zomato-data-.csv')

# %%
dat.head(2)
# Out:
#              name online_order book_table   rate  votes  \
# 0           Jalsa          Yes        Yes  4.1/5    775
# 1  Spice Elephant          Yes         No  4.1/5    787
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet

# %%
dat
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
dat['rate'].max()
# Out:
# '4.6/5'

# %%
# first few rows
dat.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
# last few rows
dat.tail()
# Out:
#                  name online_order book_table   rate  votes  \
# 143  Melting Melodies           No         No  3.3/5      0
# 144   New Indraprasta           No         No  3.3/5      0
# 145      Anna Kuteera          Yes         No  4.0/5    771
# 146            Darbar           No         No  3.0/5     98
# 147     Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 143                          100          Dining
# 144                          150          Dining
# 145                          450          Dining
# 146                          800          Dining
# 147                          200          Dining

# %%
# check shape
dat.shape
# Out:
# (148, 7)

# %%
# get columns
dat.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes',
#        'approx_cost(for two people)', 'listed_in(type)'],
#       dtype='object')

# %%
# get basic info
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
dat.isnull()
# Out:
#       name  online_order  book_table   rate  votes  \
# 0    False         False       False  False  False
# 1    False         False       False  False  False
# 2    False         False       False  False  False
# 3    False         False       False  False  False
# 4    False         False       False  False  False
# ..     ...           ...         ...    ...    ...
# 143  False         False       False  False  False
# 144  False         False       False  False  False
# 145  False         False       False  False  False
# 146  False         False       False  False  False
# 147  False         False       False  False  False
#
#      approx_cost(for two people)  listed_in(type)
# 0                          False            False
# 1                          False            False
# 2                          False            False
# 3                          False            False
# 4                          False            False
# ...

# %%
# gives the sum of how many null values are there in each column
dat.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
# gives summary for numerical columns
dat.describe()
# Out:
#              votes  approx_cost(for two people)
# count   148.000000                   148.000000
# mean    264.810811                   418.243243
# std     653.676951                   223.085098
# min       0.000000                   100.000000
# 25%       6.750000                   200.000000
# 50%      43.500000                   400.000000
# 75%     221.750000                   600.000000
# max    4884.000000                   950.000000

# %%
# Data cleaning

# %%
# drop a column
dat.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes',
#        'approx_cost(for two people)', 'listed_in(type)'],
#       dtype='object')

# %%
dat.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
# drop online_order column, inplace = True
"""
by default axis=0, which is row, provide index, change axis=1 to remove from column to prevent not found error
"""

dat.drop(['online_order'], axis=1, inplace=True)

# %%
dat.head()
# Out:
#                     name book_table   rate  votes  \
# 0                  Jalsa        Yes  4.1/5    775
# 1         Spice Elephant         No  4.1/5    787
# 2        San Churro Cafe         No  3.8/5    918
# 3  Addhuri Udupi Bhojana         No  3.7/5     88
# 4          Grand Village         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
# drop rows with missing values
dat.dropna()
# Out:
#                       name book_table   rate  votes  \
# 0                    Jalsa        Yes  4.1/5    775
# 1           Spice Elephant         No  4.1/5    787
# 2          San Churro Cafe         No  3.8/5    918
# 3    Addhuri Udupi Bhojana         No  3.7/5     88
# 4            Grand Village         No  3.8/5    166
# ..                     ...        ...    ...    ...
# 143       Melting Melodies         No  3.3/5      0
# 144        New Indraprasta         No  3.3/5      0
# 145           Anna Kuteera         No  4.0/5    771
# 146                 Darbar         No  3.0/5     98
# 147          Vijayalakshmi         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# 2                            800          Buffet
# 3                            300          Buffet
# 4                            600          Buffet
# ...

# %%
# locate particular index
dat.iloc[0,0]
# Out:
# 'Jalsa'

# %%
dat.iloc[4,5]
# Out:
# 'Buffet'

# %%
dat['name']
# Out:
# 0                      Jalsa
# 1             Spice Elephant
# 2            San Churro Cafe
# 3      Addhuri Udupi Bhojana
# 4              Grand Village
#                ...
# 143         Melting Melodies
# 144          New Indraprasta
# 145             Anna Kuteera
# 146                   Darbar
# 147            Vijayalakshmi
# Name: name, Length: 148, dtype: object

# %%
dat.iloc[0,0] = None

# %%
dat.head()
# Out:
#                     name book_table   rate  votes  \
# 0                   None        Yes  4.1/5    775
# 1         Spice Elephant         No  4.1/5    787
# 2        San Churro Cafe         No  3.8/5    918
# 3  Addhuri Udupi Bhojana         No  3.7/5     88
# 4          Grand Village         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
dat.isnull()
# Out:
#       name  book_table   rate  votes  approx_cost(for two people)  \
# 0     True       False  False  False                        False
# 1    False       False  False  False                        False
# 2    False       False  False  False                        False
# 3    False       False  False  False                        False
# 4    False       False  False  False                        False
# ..     ...         ...    ...    ...                          ...
# 143  False       False  False  False                        False
# 144  False       False  False  False                        False
# 145  False       False  False  False                        False
# 146  False       False  False  False                        False
# 147  False       False  False  False                        False
#
#      listed_in(type)
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ..               ...
# ...

# %%
# drop column with null value
dat.dropna(inplace=True)

# %%
dat
# Out:
#                       name book_table   rate  votes  \
# 1           Spice Elephant         No  4.1/5    787
# 2          San Churro Cafe         No  3.8/5    918
# 3    Addhuri Udupi Bhojana         No  3.7/5     88
# 4            Grand Village         No  3.8/5    166
# 5          Timepass Dinner         No  3.8/5    286
# ..                     ...        ...    ...    ...
# 143       Melting Melodies         No  3.3/5      0
# 144        New Indraprasta         No  3.3/5      0
# 145           Anna Kuteera         No  4.0/5    771
# 146                 Darbar         No  3.0/5     98
# 147          Vijayalakshmi         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 1                            800          Buffet
# 2                            800          Buffet
# 3                            300          Buffet
# 4                            600          Buffet
# 5                            600          Buffet
# ...

# %%
dat.iloc[0,0]
# Out:
# 'Spice Elephant'

# %%
# rename columns
dat.rename(columns={'approx_cost(for two people)': 'approx_cost'}, inplace=True)

# %%
dat.head()
# Out:
#                     name book_table   rate  votes  approx_cost listed_in(type)
# 1         Spice Elephant         No  4.1/5    787          800          Buffet
# 2        San Churro Cafe         No  3.8/5    918          800          Buffet
# 3  Addhuri Udupi Bhojana         No  3.7/5     88          300          Buffet
# 4          Grand Village         No  3.8/5    166          600          Buffet
# 5        Timepass Dinner         No  3.8/5    286          600          Buffet

# %%
# dat['column_name'].fillna(dat['column_name'].mean(), inplace=True)

# %%
dat['name'].value_counts()
# Out:
# name
# San Churro Cafe          2
# Onesta                   2
# CAFE NOVA                2
# Addhuri Udupi Bhojana    1
# Grand Village            1
#                         ..
# Melting Melodies         1
# New Indraprasta          1
# Anna Kuteera             1
# Darbar                   1
# Vijayalakshmi            1
# Name: count, Length: 144, dtype: int64

# %%
x = dat.iloc[0,2]

# %%
x
# Out:
# '4.1/5'

# %%
type(x)
# Out:
# str

# %%
x.strip('/')
# Out:
# '4.1/5'

# %%
x = x[:3]

# %%
x
float(x)
# Out:
# 4.1

# %%
def convert_rate(x):
    x = x[:3]
    return float(x)

# %%
dat['rate'] = dat['rate'].apply(convert_rate)

#apply a custom function to a particular column on a data set

# %%
dat
# Out:
#                       name book_table  rate  votes  approx_cost  \
# 1           Spice Elephant         No   4.1    787          800
# 2          San Churro Cafe         No   3.8    918          800
# 3    Addhuri Udupi Bhojana         No   3.7     88          300
# 4            Grand Village         No   3.8    166          600
# 5          Timepass Dinner         No   3.8    286          600
# ..                     ...        ...   ...    ...          ...
# 143       Melting Melodies         No   3.3      0          100
# 144        New Indraprasta         No   3.3      0          150
# 145           Anna Kuteera         No   4.0    771          450
# 146                 Darbar         No   3.0     98          800
# 147          Vijayalakshmi         No   3.9     47          200
#
#     listed_in(type)
# 1            Buffet
# 2            Buffet
# 3            Buffet
# 4            Buffet
# 5            Buffet
# ..              ...
# 143          Dining
# 144          Dining
# ...

# %%
high_rated = dat[dat['rate'] > 4.5]

# %%
high_rated
# Out:
#       name book_table  rate  votes  approx_cost listed_in(type)
# 7   Onesta        Yes   4.6   2556          600           Cafes
# 44  Onesta        Yes   4.6   2556          600           other

# %%
dat.drop_duplicates(inplace=True)

# %%
dat.shape
# Out:
# (147, 6)

# %%
dat.head()
# Out:
#                     name book_table  rate  votes  approx_cost listed_in(type)
# 1         Spice Elephant         No   4.1    787          800          Buffet
# 2        San Churro Cafe         No   3.8    918          800          Buffet
# 3  Addhuri Udupi Bhojana         No   3.7     88          300          Buffet
# 4          Grand Village         No   3.8    166          600          Buffet
# 5        Timepass Dinner         No   3.8    286          600          Buffet

# %%
# count the number of values in particular column
dat['name'].value_counts()
# Out:
# name
# San Churro Cafe          2
# Onesta                   2
# CAFE NOVA                2
# Addhuri Udupi Bhojana    1
# Grand Village            1
#                         ..
# Melting Melodies         1
# New Indraprasta          1
# Anna Kuteera             1
# Darbar                   1
# Vijayalakshmi            1
# Name: count, Length: 144, dtype: int64

# %%
# group by function to group by particular column and perform operations
dat.groupby('book_table')['rate'].mean()
# Out:
# book_table
# No     3.601429
# Yes    4.200000
# Name: rate, dtype: float64

# %%
dat.sort_values('rate', ascending=False)
# Out:
#                                          name book_table  rate  votes  \
# 7                                      Onesta        Yes   4.6   2556
# 44                                     Onesta        Yes   4.6   2556
# 38                          Empire Restaurant         No   4.4   4884
# 86                              Meghana Foods         No   4.4   4401
# 52                     Corner House Ice Cream         No   4.3    345
# ..                                        ...        ...   ...    ...
# 124  Kwality Wall's Swirl's Happiness Station         No   2.9     25
# 138              Sri Murari Family Restaurant         No   2.9      0
# 36                             Fast And Fresh         No   2.8     91
# 31                                 Foodiction         No   2.8    506
# 94                            Nandhini Deluxe         No   2.6    283
#
#      approx_cost listed_in(type)
# 7            600           Cafes
# 44           600           other
# ...

# %%
dat['cost_per_person'] = dat['approx_cost'] / dat['votes']

# %%
dat.head()
# Out:
#                     name book_table  rate  votes  approx_cost listed_in(type)  \
# 1         Spice Elephant         No   4.1    787          800          Buffet
# 2        San Churro Cafe         No   3.8    918          800          Buffet
# 3  Addhuri Udupi Bhojana         No   3.7     88          300          Buffet
# 4          Grand Village         No   3.8    166          600          Buffet
# 5        Timepass Dinner         No   3.8    286          600          Buffet
#
#    cost_per_person
# 1         1.016518
# 2         0.871460
# 3         3.409091
# 4         3.614458
# 5         2.097902

# %%
# check corelation
dat[['rate', 'votes']].corr()
# Out:
#            rate     votes
# rate   1.000000  0.486903
# votes  0.486903  1.000000

# %%
# top 10 voted
top_10_voted = dat.nlargest(10, 'votes')

# %%
top_10_voted
# Out:
#                   name book_table  rate  votes  approx_cost listed_in(type)  \
# 38   Empire Restaurant         No   4.4   4884          750           other
# 86       Meghana Foods         No   4.4   4401          600          Dining
# 7               Onesta        Yes   4.6   2556          600           Cafes
# 44              Onesta        Yes   4.6   2556          600           other
# 65         Kabab Magic         No   4.1   1720          400          Dining
# 37     Szechuan Dragon         No   4.2   1647          600          Dining
# 54        Roving Feast         No   4.0   1047          450          Dining
# 2      San Churro Cafe         No   3.8    918          800          Buffet
# 14     San Churro Cafe         No   3.8    918          800           Cafes
# 67  Gustoes Beer House         No   4.1    868          700          Dining
#
#     cost_per_person
# 38         0.153563
# 86         0.136333
# 7          0.234742
# 44         0.234742
# 65         0.232558
# ...
